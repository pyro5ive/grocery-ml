# %%
from experiment_runner import ExperimentRunner

runner = ExperimentRunner();
runner.run();
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ExperimentRunner
#       3 runner = ExperimentRunner();
#       4 runner.run();
#
# ModuleNotFoundError: No module named 'ExperimentRunner'
