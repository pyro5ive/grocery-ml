# %%
import pandas as pd
from pathlib import Path
from typing import List, Dict, Any, Optional, Tuple
import os
from datetime import datetime

from grocery_ml import GroceryML
from hidden_layer_param_builder import HiddenLayerParamSetBuilder

pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.float_format", lambda x: f"{x:.6f}")
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 2000)

print(os.getcwd())
# print("GPUs Available:", tf.config.list_physical_devices('GPU'))
#tf.debugging.set_log_device_placement(True)
# Out:
# C:\Users\steve\source\repos\grocery-ml

# %%
groceryML = GroceryML();
groceryML.build_combined_df(use_neg_samples=True)
ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
##groceryML.export_df_to_excel_table(groceryML.combined_df, f"groceryml-combined_df-{ts}", "combined_df")
# Out:
# build_combined_df(use_neg_samples = True)
# creating target col: didBuy_target
# use_neg_samples is true
# insert_negative_samples()
# build_habit_frequency_for_training()
# compute_habit_frequency_map()
# build_trip_level_features()
# build_purchase_item_freq_cols()

# %%
from pandas import to_datetime
d1 = to_datetime("2025-12-30")
pred_df1 = groceryML.RunPredictionsOnly(groceryML.combined_df, modelPath, prediction_date=d1)
modelPath = r"exp\keras\2025_12_28_00_34_58\e12__l256-128-64__ep15__oa_sigmoid__166602"

d1 = to_datetime("2025-12-31")
pred_df1 = groceryML.RunPredictionsOnly(groceryML.combined_df, modelPath, prediction_date=d1)
groceryML.export_df_to_excel_table(pred_df1, f"pred_df-12-31-2025-{ts}", "combined_df")

d1 = to_datetime("2026-01-01")
pred_df2 = groceryML.RunPredictionsOnly(groceryML.combined_df,  modelPath, prediction_date = d1)
groceryML.export_df_to_excel_table(pred_df2, f"pred_df-01-01-2026-{ts}", "combined_df")
# Out:
# RunPredictionsOnly()  prediction_date: 2025-12-30 00:00:00
#  build_prediction_input()   Prediction date: 2025-12-30
# recompute_habit_frequency_for_prediction_time()
# compute_habit_frequency_map()
# normalize_features()
# Running Model.Predict()
# 23/23 [==============================] - 0s 727us/step
# RunPredictionsOnly()  prediction_date: 2025-12-31 00:00:00
#  build_prediction_input()   Prediction date: 2025-12-31
# recompute_habit_frequency_for_prediction_time()
# compute_habit_frequency_map()
# normalize_features()
# Running Model.Predict()
# 23/23 [==============================] - 0s 727us/step
# Writing XLSX: pred_df-12-31-2025-2025_12_28_01_07_31.xlsx
#    XLSX Done: pred_df-12-31-2025-2025_12_28_01_07_31.xlsx
# RunPredictionsOnly()  prediction_date: 2026-01-01 00:00:00
#  build_prediction_input()   Prediction date: 2026-01-01
# recompute_habit_frequency_for_prediction_time()
# compute_habit_frequency_map()
# normalize_features()
# Running Model.Predict()
# ...
