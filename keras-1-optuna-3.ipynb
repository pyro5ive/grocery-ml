# %%
import pandas as pd
from pathlib import Path
from typing import List, Dict, Any, Optional, Tuple
import os
from datetime import datetime
import pdb;
from grocery_ml_tensorflow import GroceryML
from grocery_ml_core import GroceryMLCore
from hidden_layer_param_builder import HiddenLayerParamSetBuilder
import tensorflow as tf

pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.float_format", lambda x: f"{x:.6f}")
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 2000)

print(os.getcwd())
# print("GPUs Available:", tf.config.list_physical_devices('GPU'))
#tf.debugging.set_log_device_placement(True)

# def run_all_experiments(df, model_param_sets, output_dir):
#     total = len(model_param_sets)
#     print(f"run_all_experiments() when: {datetime.now()}  output_dir: {output_dir}");
#     for index, params in enumerate(model_param_sets, 1):
#         print(f"Running Exp {index}/{total}...")
#         groceryML.run_experiment(df,  params["buildParams"], params["trainParams"], output_dir)


try:
    groceryML = GroceryML();
    groceryMLCore = GroceryMLCore();
    groceryML.build_training_df()
    if groceryML.training_df is None:
        raise();
    ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    # groceryML.training_df.to_csv(f"training_df-{ts}.csv");
except Exception as ex: 
    print(ex)
    ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    groceryML.training_df.to_csv(f"training_df-{ts}-exception.csv");
# Out:
# C:\Users\steve\source\repos\grocery-ml
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done

# %%
import optuna 
def objective(trial):

    lr = trial.suggest_float("learning_rate", 0.0001, 0.0001)
    depth = trial.suggest_int("depth", 3, 3)
    units = trial.suggest_int("units", 64, 64)
    embedding_dim = trial.suggest_int("embedding_dim", 30, 500, step=5)
    epochs = trial.suggest_int("epochs", 50, 50)
    # output_activation = trial.suggest_categorical("output_activation", ["sigmoid", "linear"])
    output_activation = "sigmoid"
    metrics = ["AUC", "Precision", "Recall"]
    # metrics = ["Accuracy", "MAE", "MSE", "MAPE", "MSLE", "Precision", "Recall", "AUC",  "BinaryCrossentropy", "RootMeanSquaredError"]
    
    layers_cfg = []
    for _ in range(depth):
        layers_cfg.append({ "units": units, "activation": "relu" })

    build_params = {
        "embedding_dim": embedding_dim,
        "layers": layers_cfg,
        "output_activation": output_activation,
        "optimizer": "adam",
        "learning_rate": lr,
        "loss": "binary_crossentropy" if output_activation == "sigmoid" else "mse",
        "metrics": metrics
    }

    train_params = {
        "epochs": epochs,
        "batch_size": 32,
     
    }

    outputDir = f"f:/exp/keras/optuna/{trial.study.study_name}/trial-{trial.number}"        
    groceryML.run_experiment(groceryML.training_df, build_params, train_params, outputDir)

    return groceryML.last_val_auc
############################################################################


sampler = optuna.samplers.TPESampler()

study_name = f"grocery_ml_tuning_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
study = optuna.create_study(
    study_name= study_name,
    sampler=sampler,
    direction="maximize",   # or minimize — see note below
    storage="sqlite:///optuna_grocery.db",
    load_if_exists=True
)


study.optimize(objective, n_trials=250)
# Out:
# [I 2026-01-15 14:02:28,323] A new study created in RDB with name: grocery_ml_tuning_20260115_140227
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859
# run_experiment()  when: 2026-01-15 14:02:28.373878 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:02:40.320499
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 2ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859\normalized_training_df-e430_l64-64-64_ep50_sig_859.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859\normalized_training_df-e430_l64-64-64_ep50_sig_859.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859\predictions-e430_l64-64-64_ep50_sig_859.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859\predictions-e430_l64-64-64_ep50_sig_859.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859\model\assets
# [I 2026-01-15 14:04:48,977] Trial 0 finished with value: 0.89242023229599 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 430, 'epochs': 50}. Best is trial 0 with value: 0.89242023229599.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-0\e430_l64-64-64_ep50_sig_859
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327
# run_experiment()  when: 2026-01-15 14:04:49.142236 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:05:47.142476
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327\normalized_training_df-e200_l64-64-64_ep50_sig_327.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327\normalized_training_df-e200_l64-64-64_ep50_sig_327.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327\predictions-e200_l64-64-64_ep50_sig_327.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327\predictions-e200_l64-64-64_ep50_sig_327.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327\model\assets
# [I 2026-01-15 14:07:21,327] Trial 1 finished with value: 0.8943110108375549 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 200, 'epochs': 50}. Best is trial 1 with value: 0.8943110108375549.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-1\e200_l64-64-64_ep50_sig_327
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840
# run_experiment()  when: 2026-01-15 14:07:21.365707 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:07:47.211163
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 3ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840\normalized_training_df-e465_l64-64-64_ep50_sig_840.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840\normalized_training_df-e465_l64-64-64_ep50_sig_840.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840\predictions-e465_l64-64-64_ep50_sig_840.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840\predictions-e465_l64-64-64_ep50_sig_840.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840\model\assets
# [I 2026-01-15 14:09:26,081] Trial 2 finished with value: 0.8955390453338623 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 465, 'epochs': 50}. Best is trial 2 with value: 0.8955390453338623.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-2\e465_l64-64-64_ep50_sig_840
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275
# run_experiment()  when: 2026-01-15 14:09:26.119475 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:09:39.710457
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275\normalized_training_df-e55_l64-64-64_ep50_sig_275.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275\normalized_training_df-e55_l64-64-64_ep50_sig_275.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275\predictions-e55_l64-64-64_ep50_sig_275.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275\predictions-e55_l64-64-64_ep50_sig_275.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275\model\assets
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-3\e55_l64-64-64_ep50_sig_275
# [I 2026-01-15 14:11:54,255] Trial 3 finished with value: 0.8936344385147095 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 55, 'epochs': 50}. Best is trial 2 with value: 0.8955390453338623.
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936
# run_experiment()  when: 2026-01-15 14:11:54.407321 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:12:39.640826
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936\normalized_training_df-e360_l64-64-64_ep50_sig_936.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936\normalized_training_df-e360_l64-64-64_ep50_sig_936.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936\predictions-e360_l64-64-64_ep50_sig_936.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936\predictions-e360_l64-64-64_ep50_sig_936.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936\model\assets
# [I 2026-01-15 14:13:33,945] Trial 4 finished with value: 0.8744532465934753 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 360, 'epochs': 50}. Best is trial 2 with value: 0.8955390453338623.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-4\e360_l64-64-64_ep50_sig_936
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227
# run_experiment()  when: 2026-01-15 14:13:33.987224 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:13:54.307504
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227\normalized_training_df-e300_l64-64-64_ep50_sig_227.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227\normalized_training_df-e300_l64-64-64_ep50_sig_227.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227\predictions-e300_l64-64-64_ep50_sig_227.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227\predictions-e300_l64-64-64_ep50_sig_227.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227\model\assets
# [I 2026-01-15 14:14:57,541] Trial 5 finished with value: 0.879337728023529 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 300, 'epochs': 50}. Best is trial 2 with value: 0.8955390453338623.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-5\e300_l64-64-64_ep50_sig_227
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134
# run_experiment()  when: 2026-01-15 14:14:57.583347 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:15:11.635509
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 1s 11ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134\normalized_training_df-e315_l64-64-64_ep50_sig_134.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134\normalized_training_df-e315_l64-64-64_ep50_sig_134.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134\predictions-e315_l64-64-64_ep50_sig_134.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134\predictions-e315_l64-64-64_ep50_sig_134.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134\model\assets
# [save_model] saving model weights (separate file)
# [I 2026-01-15 14:18:44,095] Trial 6 finished with value: 0.8880825638771057 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 315, 'epochs': 50}. Best is trial 2 with value: 0.8955390453338623.
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-6\e315_l64-64-64_ep50_sig_134
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722
# run_experiment()  when: 2026-01-15 14:18:44.315259 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:19:47.747992
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722\normalized_training_df-e375_l64-64-64_ep50_sig_722.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722\normalized_training_df-e375_l64-64-64_ep50_sig_722.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722\predictions-e375_l64-64-64_ep50_sig_722.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722\predictions-e375_l64-64-64_ep50_sig_722.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722\model\assets
# [I 2026-01-15 14:21:49,707] Trial 7 finished with value: 0.8962991237640381 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 375, 'epochs': 50}. Best is trial 7 with value: 0.8962991237640381.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-7\e375_l64-64-64_ep50_sig_722
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171
# run_experiment()  when: 2026-01-15 14:21:49.745423 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:22:07.007827
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171\normalized_training_df-e300_l64-64-64_ep50_sig_171.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171\normalized_training_df-e300_l64-64-64_ep50_sig_171.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171\predictions-e300_l64-64-64_ep50_sig_171.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171\predictions-e300_l64-64-64_ep50_sig_171.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171\model\assets
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-8\e300_l64-64-64_ep50_sig_171
# [I 2026-01-15 14:24:38,376] Trial 8 finished with value: 0.8719691634178162 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 300, 'epochs': 50}. Best is trial 7 with value: 0.8962991237640381.
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122
# run_experiment()  when: 2026-01-15 14:24:38.534637 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:25:27.205563
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122\normalized_training_df-e160_l64-64-64_ep50_sig_122.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122\normalized_training_df-e160_l64-64-64_ep50_sig_122.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122\predictions-e160_l64-64-64_ep50_sig_122.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122\predictions-e160_l64-64-64_ep50_sig_122.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122\model\assets
# [I 2026-01-15 14:26:19,853] Trial 9 finished with value: 0.9004467725753784 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 160, 'epochs': 50}. Best is trial 9 with value: 0.9004467725753784.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-9\e160_l64-64-64_ep50_sig_122
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208
# run_experiment()  when: 2026-01-15 14:26:19.904385 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:27:03.010208
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 3ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208\normalized_training_df-e170_l64-64-64_ep50_sig_208.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208\normalized_training_df-e170_l64-64-64_ep50_sig_208.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208\predictions-e170_l64-64-64_ep50_sig_208.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208\predictions-e170_l64-64-64_ep50_sig_208.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208\model\assets
# [I 2026-01-15 14:30:10,584] Trial 10 finished with value: 0.8870490789413452 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 170, 'epochs': 50}. Best is trial 9 with value: 0.9004467725753784.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-10\e170_l64-64-64_ep50_sig_208
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146
# run_experiment()  when: 2026-01-15 14:30:10.636907 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:30:23.216746
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 800us/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146\normalized_training_df-e110_l64-64-64_ep50_sig_146.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146\normalized_training_df-e110_l64-64-64_ep50_sig_146.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146\predictions-e110_l64-64-64_ep50_sig_146.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146\predictions-e110_l64-64-64_ep50_sig_146.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146\model\assets
# [I 2026-01-15 14:32:02,743] Trial 11 finished with value: 0.8963500261306763 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 110, 'epochs': 50}. Best is trial 9 with value: 0.9004467725753784.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-11\e110_l64-64-64_ep50_sig_146
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186
# run_experiment()  when: 2026-01-15 14:32:02.808730 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:33:11.525191
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 9ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186\normalized_training_df-e70_l64-64-64_ep50_sig_186.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186\normalized_training_df-e70_l64-64-64_ep50_sig_186.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186\predictions-e70_l64-64-64_ep50_sig_186.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186\predictions-e70_l64-64-64_ep50_sig_186.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186\model\assets
# [I 2026-01-15 14:37:11,760] Trial 12 finished with value: 0.8925452828407288 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 70, 'epochs': 50}. Best is trial 9 with value: 0.9004467725753784.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-12\e70_l64-64-64_ep50_sig_186
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974
# run_experiment()  when: 2026-01-15 14:37:12.048283 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:38:22.544379
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 7ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974\normalized_training_df-e150_l64-64-64_ep50_sig_974.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974\normalized_training_df-e150_l64-64-64_ep50_sig_974.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974\predictions-e150_l64-64-64_ep50_sig_974.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974\predictions-e150_l64-64-64_ep50_sig_974.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974\model\assets
# [I 2026-01-15 14:42:25,461] Trial 13 finished with value: 0.8821043968200684 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 150, 'epochs': 50}. Best is trial 9 with value: 0.9004467725753784.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-13\e150_l64-64-64_ep50_sig_974
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170
# run_experiment()  when: 2026-01-15 14:42:25.747105 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 14:42:44.984433
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170\normalized_training_df-e115_l64-64-64_ep50_sig_170.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170\normalized_training_df-e115_l64-64-64_ep50_sig_170.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170\predictions-e115_l64-64-64_ep50_sig_170.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170\predictions-e115_l64-64-64_ep50_sig_170.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170\model\assets
# [I 2026-01-15 14:43:37,528] Trial 14 finished with value: 0.8919521570205688 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 115, 'epochs': 50}. Best is trial 9 with value: 0.9004467725753784.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-14\e115_l64-64-64_ep50_sig_170
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-15\e220_l64-64-64_ep50_sig_141
# ...
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 800us/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562\normalized_training_df-e40_l64-64-64_ep50_sig_562.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562\normalized_training_df-e40_l64-64-64_ep50_sig_562.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562\predictions-e40_l64-64-64_ep50_sig_562.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562\predictions-e40_l64-64-64_ep50_sig_562.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562\model\assets
# [I 2026-01-15 23:33:21,297] Trial 211 finished with value: 0.8940838575363159 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 40, 'epochs': 50}. Best is trial 50 with value: 0.9107070565223694.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-211\e40_l64-64-64_ep50_sig_562
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786
# run_experiment()  when: 2026-01-15 23:33:21.342199 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 23:33:39.572829
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786\normalized_training_df-e30_l64-64-64_ep50_sig_786.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786\normalized_training_df-e30_l64-64-64_ep50_sig_786.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786\predictions-e30_l64-64-64_ep50_sig_786.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786\predictions-e30_l64-64-64_ep50_sig_786.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786\model\assets
# [I 2026-01-15 23:34:34,357] Trial 212 finished with value: 0.9076437950134277 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 30, 'epochs': 50}. Best is trial 50 with value: 0.9107070565223694.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-212\e30_l64-64-64_ep50_sig_786
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917
# run_experiment()  when: 2026-01-15 23:34:34.398824 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 23:34:51.132676
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 4ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917\normalized_training_df-e30_l64-64-64_ep50_sig_917.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917\normalized_training_df-e30_l64-64-64_ep50_sig_917.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917\predictions-e30_l64-64-64_ep50_sig_917.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917\predictions-e30_l64-64-64_ep50_sig_917.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917\model\assets
# [I 2026-01-15 23:38:14,778] Trial 213 finished with value: 0.9032087922096252 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 30, 'epochs': 50}. Best is trial 50 with value: 0.9107070565223694.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-213\e30_l64-64-64_ep50_sig_917
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615
# run_experiment()  when: 2026-01-15 23:38:15.036709 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 23:39:49.230307
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615\normalized_training_df-e50_l64-64-64_ep50_sig_615.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615\normalized_training_df-e50_l64-64-64_ep50_sig_615.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615\predictions-e50_l64-64-64_ep50_sig_615.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615\predictions-e50_l64-64-64_ep50_sig_615.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615\model\assets
# [I 2026-01-15 23:41:11,754] Trial 214 finished with value: 0.8911874890327454 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 50, 'epochs': 50}. Best is trial 50 with value: 0.9107070565223694.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-214\e50_l64-64-64_ep50_sig_615
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182
# run_experiment()  when: 2026-01-15 23:41:11.794428 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 23:41:38.645150
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_school_schedule_features()
# build_holiday_features()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182\normalized_training_df-e325_l64-64-64_ep50_sig_182.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182\normalized_training_df-e325_l64-64-64_ep50_sig_182.xlsx
# Writing XLSX: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182\predictions-e325_l64-64-64_ep50_sig_182.xlsx
#    XLSX Done: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182\predictions-e325_l64-64-64_ep50_sig_182.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182\model\assets
# [I 2026-01-15 23:42:37,812] Trial 215 finished with value: 0.8842685222625732 and parameters: {'learning_rate': 0.0001, 'depth': 3, 'units': 64, 'embedding_dim': 325, 'epochs': 50}. Best is trial 50 with value: 0.9107070565223694.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182\model
# Saved experiment → f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-215\e325_l64-64-64_ep50_sig_182
# Creating dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-216\e30_l64-64-64_ep50_sig_196
# run_experiment()  exp_dir: f:/exp/keras/optuna/grocery_ml_tuning_20260115_140227/trial-216\e30_l64-64-64_ep50_sig_196
# run_experiment()  when: 2026-01-15 23:42:37.853502 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-15 23:42:58.605167
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
