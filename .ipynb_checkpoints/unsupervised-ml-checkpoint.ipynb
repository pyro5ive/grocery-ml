# %%
import pandas as pd
from pathlib import Path
from typing import List, Dict, Any, Optional, Tuple
import os
from datetime import datetime
import pdb;
from grocery_ml_tensorflow import GroceryML
from grocery_ml_core import GroceryMLCore
from hidden_layer_param_builder import HiddenLayerParamSetBuilder

pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.float_format", lambda x: f"{x:.6f}")
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 2000)

print(os.getcwd())
# print("GPUs Available:", tf.config.list_physical_devices('GPU'))
#tf.debugging.set_log_device_placement(True)

def run_all_experiments(df, model_param_sets, output_dir):
    total = len(model_param_sets)
    print(f"run_all_experiments() when: {datetime.now()}  output_dir: {output_dir}");
    for index, params in enumerate(model_param_sets, 1):
        print(f"Running Exp {index}/{total}...")
        groceryML.run_experiment(df,  params["buildParams"], params["trainParams"], output_dir)


try:
    groceryML = GroceryML();
    groceryMLCore = GroceryMLCore();
    groceryML.build_training_df()
    if groceryML.training_df is None:
        raise();
    ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    groceryML.training_df.to_csv(f"training_df-{ts}.csv");
except Exception as ex: 
    print(ex)
    ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    groceryML.training_df.to_csv(f"training_df-{ts}-exception.csv");
# Out:
# C:\Users\steve\source\repos\grocery-ml
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done

# %%
# quick test shot
layers = [
    { "units": 1, "activation": "relu" }
]
modelParamsList = []
modelParamsList.append({
    "trainParams": { "epochs": 1 },
    "buildParams": {
    "embedding_dim": 1,
    "layers": layers,
    "activation": "relu",
    "output_activation": "sigmoid",
    "optimizer": "adam",
    "learning_rate": 0.01,
    "loss": "binary_crossentropy",
    "metrics": "BinaryCrossentropy"
    }
})
ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
run_all_experiments(groceryML.training_df, modelParamsList, f"exp/keras/keras-1-lrA/test-shot-no-trust-{ts}")
# Out:
# run_all_experiments() when: 2026-01-10 11:31:21.815296  output_dir: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21
# Running Exp 1/1...
# Creating dir: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994
# run_experiment()  baseDir: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994
# run_experiment()  when: 2026-01-10 11:31:21.816308 params: {'epochs': 1}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-10 11:31:23.199492
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:276: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# build_prediction_input() is done
# Running Model.Predict()
# 6/6 [==============================] - 0s 1ms/step
# Exporting extra_dataframes:
# Writing XLSX: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994\normalized_training_df.xlsx
#    XLSX Done: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994\normalized_training_df.xlsx
# Writing XLSX: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994\predictions.xlsx
#    XLSX Done: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994\predictions.xlsx
# [save_model] starting artifact save → exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994\model\assets
# INFO:tensorflow:Assets written to: exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994\model\assets
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994\model
# Saved experiment → exp/keras/keras-1-lrA/test-shot-no-trust-2026_01_10_11_31_21\e1__l1__ep1__oa_sigmoid__187994

# %%
###########################################################

modelParamsList = []
layers = [
    { "units": 64, "activation": "relu" },
    { "units": 64, "activation": "relu" },
    
]
output_activations = ["sigmoid", "linear", "tanh"]
embDims = [128,64,32,16,12]
metrics = ["Accuracy", "MAE", "MSE", "MAPE", "MSLE", "Precision", "Recall", "AUC",  "BinaryCrossentropy", "RootMeanSquaredError"]

for act in output_activations:
    for dim in embDims:
        modelParamsList.append({
            "trainParams": { "epochs": 10 },
            "buildParams": {
                "embedding_dim": dim,
                "layers": layers,
                "output_activation": act,
                "optimizer": "adam",
                "learning_rate": 0.0001,
                "loss": "binary_crossentropy" if act == "sigmoid" else "mse",
                "metrics": metrics
            }
        })

ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
run_all_experiments( groceryML.training_df, modelParamsList, f"exp/keras/keras-1-lrA/{ts}")
# Out:
# run_all_experiments() when: 2026-01-10 11:32:12.074561  output_dir: exp/keras/keras-1-lrA/2026_01_10_11_32_12
# Running Exp 1/15...
# Creating dir: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926
# run_experiment()  baseDir: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926
# run_experiment()  when: 2026-01-10 11:32:12.076341 params: {'epochs': 10}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-10 11:32:21.354845
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:276: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# build_trip_interveral_feautres()
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# create_item_supply_level_feat()
# normalize_features()
# build_prediction_input() is done
# Running Model.Predict()
# 6/6 [==============================] - 0s 2ms/step
# Exporting extra_dataframes:
# Writing XLSX: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926\normalized_training_df.xlsx
#    XLSX Done: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926\normalized_training_df.xlsx
# Writing XLSX: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926\predictions.xlsx
#    XLSX Done: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926\predictions.xlsx
# [save_model] starting artifact save → exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926\model\assets
# INFO:tensorflow:Assets written to: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926\model\assets
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926\model
# Saved experiment → exp/keras/keras-1-lrA/2026_01_10_11_32_12\e128__l64-64__ep10__oa_sigmoid__171926
# Running Exp 2/15...
# Creating dir: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e64__l64-64__ep10__oa_sigmoid__176237
# run_experiment()  baseDir: exp/keras/keras-1-lrA/2026_01_10_11_32_12\e64__l64-64__ep10__oa_sigmoid__176237
# run_experiment()  when: 2026-01-10 11:33:09.764307 params: {'epochs': 10}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-10 11:33:18.094711
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:276: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()

# %%
###########################################################

modelParamsList = []
layers = [
    { "units": 32, "activation": "relu" },
    { "units": 32, "activation": "relu" },
    
    
]
output_activations = ["sigmoid", "linear", "tanh"]
embDims = [128,64,48,32,16,12]
metrics = ["Accuracy", "MAE", "MSE", "MAPE", "MSLE", "Precision", "Recall", "AUC",  "BinaryCrossentropy", "RootMeanSquaredError"]

for act in output_activations:
    for dim in embDims:
        modelParamsList.append({
            "trainParams": { "epochs": 10 },
            "buildParams": {
                "embedding_dim": dim,
                "layers": layers,
                "output_activation": act,
                "optimizer": "adam",
                "learning_rate": 0.0001,
                "loss": "binary_crossentropy" if act == "sigmoid" else "mse",
                "metrics": metrics
            }
        })

ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
run_all_experiments( groceryML.training_df, modelParamsList, f"exp/keras/keras-1-lrA/{ts}")

# %%
###########################################################

modelParamsList = []
layers = [
    { "units": 32, "activation": "relu" },
    { "units": 32, "activation": "relu" },
    { "units": 32, "activation": "relu" },
    { "units": 32, "activation": "relu" },
    
    
]
output_activations = ["sigmoid", "linear", "tanh"]
embDims = [128,64,48,32,16,12]
metrics = ["Accuracy", "MAE", "MSE", "MAPE", "MSLE", "Precision", "Recall", "AUC",  "BinaryCrossentropy", "RootMeanSquaredError"]

for act in output_activations:
    for dim in embDims:
        modelParamsList.append({
            "trainParams": { "epochs": 10 },
            "buildParams": {
                "embedding_dim": dim,
                "layers": layers,
                "output_activation": act,
                "optimizer": "adam",
                "learning_rate": 0.0001,
                "loss": "binary_crossentropy" if act == "sigmoid" else "mse",
                "metrics": metrics
            }
        })

ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
run_all_experiments( groceryML.training_df, modelParamsList, f"exp/keras/keras-1-lrA/{ts}")

# %%
###########################################################

modelParamsList = []
layers = [
    { "units": 64, "activation": "relu" },
    { "units": 64, "activation": "relu" },
    { "units": 64, "activation": "relu" },
    
]
output_activations = ["sigmoid", "linear", "tanh"]
embDims = [128,64,48,32,16,12]
metrics = ["Accuracy", "MAE", "MSE", "MAPE", "MSLE", "Precision", "Recall", "AUC",  "BinaryCrossentropy", "RootMeanSquaredError"]

for act in output_activations:
    for dim in embDims:
        modelParamsList.append({
            "trainParams": { "epochs": 10 },
            "buildParams": {
                "embedding_dim": dim,
                "layers": layers,
                "output_activation": act,
                "optimizer": "adam",
                "learning_rate": 0.0001,
                "loss": "binary_crossentropy" if act == "sigmoid" else "mse",
                "metrics": metrics
            }
        })

ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
run_all_experiments( groceryML.training_df, modelParamsList, f"exp/keras/keras-1-lrA/{ts}")

# %%
###########################################################

modelParamsList = []
layers = [
    { "units": 64, "activation": "relu" },
    { "units": 32, "activation": "relu" },
    { "units": 32, "activation": "relu" },
    
]
output_activations = ["sigmoid", "linear", "tanh"]
embDims = [128,64,48,32,16,12]
metrics = ["Accuracy", "MAE", "MSE", "MAPE", "MSLE", "Precision", "Recall", "AUC",  "BinaryCrossentropy", "RootMeanSquaredError"]

for act in output_activations:
    for dim in embDims:
        modelParamsList.append({
            "trainParams": { "epochs": 10 },
            "buildParams": {
                "embedding_dim": dim,
                "layers": layers,
                "output_activation": act,
                "optimizer": "adam",
                "learning_rate": 0.0001,
                "loss": "binary_crossentropy" if act == "sigmoid" else "mse",
                "metrics": metrics
            }
        })

ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
run_all_experiments( groceryML.training_df, modelParamsList, f"exp/keras/keras-1-lrA/{ts}")
