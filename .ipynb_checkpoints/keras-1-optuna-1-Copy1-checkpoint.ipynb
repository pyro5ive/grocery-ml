# %%
import pandas as pd
from pathlib import Path
from typing import List, Dict, Any, Optional, Tuple
import os
from datetime import datetime
import pdb;
from grocery_ml_tensorflow import GroceryML
from grocery_ml_core import GroceryMLCore
from hidden_layer_param_builder import HiddenLayerParamSetBuilder
import tensorflow as tf

pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.float_format", lambda x: f"{x:.6f}")
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 2000)

print(os.getcwd())
# print("GPUs Available:", tf.config.list_physical_devices('GPU'))
#tf.debugging.set_log_device_placement(True)

# def run_all_experiments(df, model_param_sets, output_dir):
#     total = len(model_param_sets)
#     print(f"run_all_experiments() when: {datetime.now()}  output_dir: {output_dir}");
#     for index, params in enumerate(model_param_sets, 1):
#         print(f"Running Exp {index}/{total}...")
#         groceryML.run_experiment(df,  params["buildParams"], params["trainParams"], output_dir)


try:
    groceryML = GroceryML();
    groceryMLCore = GroceryMLCore();
    groceryML.build_training_df()
    if groceryML.training_df is None:
        raise();
    ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    # groceryML.training_df.to_csv(f"training_df-{ts}.csv");
except Exception as ex: 
    print(ex)
    ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    groceryML.training_df.to_csv(f"training_df-{ts}-exception.csv");
# Out:
# C:\Users\steve\source\repos\grocery-ml
# Building Training DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Training DF: Done

# %%
import optuna 
def new_objective(trial):

    lr = trial.suggest_float("learning_rate", 0.001, 0.001)
    depth = trial.suggest_int("depth", 5, 20, step=5)
    base_units = trial.suggest_int("base_units", 512, 2048, step=12)
    decay = trial.suggest_float("decay", 0.2, 0.6)
    embedding_dim = trial.suggest_int("embedding_dim", 20, 300, step=10)
    epochs = trial.suggest_int("epochs", 30, 200, step=10)
    output_activation = "sigmoid"
    metrics = ["AUC", "Precision", "Recall"]
    
    layers_cfg = []
    current_units = base_units
    
    for i in range(depth):
        layers_cfg.append({
            "units": int(current_units),
            "activation": "relu"
        })
        current_units = max(4, current_units * decay)

    build_params = {
        "embedding_dim": embedding_dim,
        "layers": layers_cfg,
        "output_activation": output_activation,
        "optimizer": "adam",
        "learning_rate": lr,
        "loss": "binary_crossentropy" if output_activation == "sigmoid" else "mse",
        "metrics": metrics
    }

    train_params = { "epochs": epochs, "batch_size": 32 }
    days = 10
    start_date = pd.Timestamp.now()
    outputDir = f"f:/exp/keras/optuna/{trial.study.study_name}/trial-{trial.number}"
    groceryML.run_experiment_with_consecutive_predictions( groceryML.training_df, build_params, train_params,  outputDir, start_date,  days)                     
    # groceryML.run_experiment(groceryML.training_df, build_params, train_params, outputDir)

    return groceryML.last_val_auc
############################################################################

# %%
sampler = optuna.samplers.TPESampler()

study_name = f"stuff-fixed-{datetime.now().strftime('%Y%m%d_%H%M%S')}"
study = optuna.create_study(
    study_name= study_name,
    sampler=sampler,
    direction="maximize",   # or minimize — see note below
    storage="sqlite:///optuna_grocery.db",
    load_if_exists=True
)
study.optimize(new_objective, n_trials=200)
# Out:
# [I 2026-01-19 05:42:39,070] A new study created in RDB with name: stuff-fixed-20260119_054238
# Creating dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30
# run_experiment_with_consecutive_predictions() exp_dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30
# when: 2026-01-19 05:42:39.120189 params: {'epochs': 200, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-19 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_44_26.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_44_26.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-20 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_45_04.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_45_04.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-21 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_45_42.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_45_42.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-22 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_46_20.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_46_20.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-23 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_46_58.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_46_58.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-24 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_47_36.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_47_36.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-25 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_48_14.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_48_14.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-26 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_48_52.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_48_52.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-27 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_49_30.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_49_30.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-28 05:42:39.119189
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_50_07.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_50_07.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 11ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30\normalized_training_df-e30_l1964-983-492-246-123-61-30.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30\normalized_training_df-e30_l1964-983-492-246-123-61-30.xlsx
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30\consecutive_predictions-e30_l1964-983-492-246-123-61-30.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30\consecutive_predictions-e30_l1964-983-492-246-123-61-30.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30\model\assets
# [I 2026-01-19 05:51:43,520] Trial 0 finished with value: 0.8854907155036926 and parameters: {'learning_rate': 0.001, 'depth': 20, 'base_units': 1964, 'decay': 0.5008118342902097, 'embedding_dim': 30, 'epochs': 200}. Best is trial 0 with value: 0.8854907155036926.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30\model
# Saved experiment → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-0\e30_l1964-983-492-246-123-61-30
# Creating dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-
# run_experiment_with_consecutive_predictions() exp_dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-
# when: 2026-01-19 05:51:43.556747 params: {'epochs': 100, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-19 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_52_39.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_52_39.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-20 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_53_19.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_53_19.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-21 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_54_00.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_54_00.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-22 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_54_41.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_54_41.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-23 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_55_22.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_55_22.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-24 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_56_02.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_56_02.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-25 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_56_44.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_56_44.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-26 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_57_25.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_57_25.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-27 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_58_06.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_58_06.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-28 05:51:43.555352
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_05_58_48.xlsx
#    XLSX Done: ./live_df-2026_01_19_05_58_48.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-\normalized_training_df-e250_l1244-296-70-16-4-4-4-4-4-.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-\normalized_training_df-e250_l1244-296-70-16-4-4-4-4-4-.xlsx
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-\consecutive_predictions-e250_l1244-296-70-16-4-4-4-4-4-.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-\consecutive_predictions-e250_l1244-296-70-16-4-4-4-4-4-.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-\model\assets
# [I 2026-01-19 05:59:44,240] Trial 1 finished with value: 0.8663290739059448 and parameters: {'learning_rate': 0.001, 'depth': 15, 'base_units': 1244, 'decay': 0.23861513184201782, 'embedding_dim': 250, 'epochs': 100}. Best is trial 0 with value: 0.8854907155036926.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-\model
# Saved experiment → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-1\e250_l1244-296-70-16-4-4-4-4-4-
# Creating dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_
# run_experiment_with_consecutive_predictions() exp_dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_
# when: 2026-01-19 05:59:44.348406 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-19 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_01_23.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_01_23.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-20 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_02_05.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_02_05.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-21 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_02_46.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_02_46.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-22 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_03_28.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_03_28.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-23 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_04_09.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_04_09.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-24 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_04_51.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_04_51.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-25 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_05_33.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_05_33.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-26 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_06_15.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_06_15.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-27 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_06_56.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_06_56.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-28 05:59:44.346405
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_07_38.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_07_38.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_\normalized_training_df-e80_l1748-925-490-259-137_ep50_.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_\normalized_training_df-e80_l1748-925-490-259-137_ep50_.xlsx
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_\consecutive_predictions-e80_l1748-925-490-259-137_ep50_.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_\consecutive_predictions-e80_l1748-925-490-259-137_ep50_.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_\model\assets
# [I 2026-01-19 06:08:29,303] Trial 2 finished with value: 0.8824399709701538 and parameters: {'learning_rate': 0.001, 'depth': 5, 'base_units': 1748, 'decay': 0.5294789023985422, 'embedding_dim': 80, 'epochs': 50}. Best is trial 0 with value: 0.8854907155036926.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_\model
# Saved experiment → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-2\e80_l1748-925-490-259-137_ep50_
# Creating dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-3\e70_l740-372-188-94-47-24-12-6-
# run_experiment_with_consecutive_predictions() exp_dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-3\e70_l740-372-188-94-47-24-12-6-
# when: 2026-01-19 06:08:29.363399 params: {'epochs': 50, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-19 06:08:29.361398
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_06_09_12.xlsx
#    XLSX Done: ./live_df-2026_01_19_06_09_12.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# ...
# build_prediction_input() prediction_date=2026-01-26 20:11:31.164756
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_19_16.xlsx
#    XLSX Done: ./live_df-2026_01_19_20_19_16.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-27 20:11:31.164756
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_20_00.xlsx
#    XLSX Done: ./live_df-2026_01_19_20_20_00.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# build_prediction_input() prediction_date=2026-01-28 20:11:31.164756
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_20_43.xlsx
#    XLSX Done: ./live_df-2026_01_19_20_20_43.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 4ms/step
# Exporting extra_dataframes:
# grocery_ml_tensorflow.export_dataframes_to_excel()
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6\normalized_training_df-e30_l1544-911-537-317-187-110-6.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6\normalized_training_df-e30_l1544-911-537-317-187-110-6.xlsx
# Writing XLSX: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6\consecutive_predictions-e30_l1544-911-537-317-187-110-6.xlsx
#    XLSX Done: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6\consecutive_predictions-e30_l1544-911-537-317-187-110-6.xlsx
# [save_model] starting artifact save → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6
# [save_model] writing training_df snapshot (parquet, pre-normalized)
# [save_model] writing training history json
# [save_model] saving model directory files
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6\model\assets
# INFO:tensorflow:Assets written to: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6\model\assets
# [I 2026-01-19 20:21:30,440] Trial 94 finished with value: 0.8686506748199463 and parameters: {'learning_rate': 0.001, 'depth': 10, 'base_units': 1544, 'decay': 0.5902448967499039, 'embedding_dim': 30, 'epochs': 190}. Best is trial 39 with value: 0.9045121073722839.
# [save_model] saving model weights (separate file)
# [save_model] all artifacts saved successfully → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6\model
# Saved experiment → f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-94\e30_l1544-911-537-317-187-110-6
# Creating dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-95\e20_l1364-774-439-249-141-80-45
# run_experiment_with_consecutive_predictions() exp_dir: f:/exp/keras/optuna/stuff-fixed-20260119_054238/trial-95\e20_l1364-774-439-249-141-80-45
# when: 2026-01-19 20:21:30.496241 params: {'epochs': 200, 'batch_size': 32}
# normalize_features()
# train_model()
# build_prediction_input() prediction_date=2026-01-19 20:21:30.495240
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# creating target col: didBuy_target
# insert_negative_samples()
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_22_46.xlsx
#    XLSX Done: ./live_df-2026_01_19_20_22_46.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-20 20:21:30.495240
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_23_29.xlsx
#    XLSX Done: ./live_df-2026_01_19_20_23_29.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 3ms/step
# build_prediction_input() prediction_date=2026-01-21 20:21:30.495240
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_24_08.xlsx
#    XLSX Done: ./live_df-2026_01_19_20_24_08.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-22 20:21:30.495240
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_24_48.xlsx
#    XLSX Done: ./live_df-2026_01_19_20_24_48.xlsx
# _build_latest_rows_df: start
# _build_latest_rows_df: done
# create_item_supply_level_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# normalize_features()
# 6/6 [==============================] - 0s 2ms/step
# build_prediction_input() prediction_date=2026-01-23 20:21:30.495240
# Building Live DF: Start
# _build_combined_df()
# _build_sources()
# creating target col: didBuy_target
# insert_negative_samples()
# C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py:349: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   additional_rcpts_df["date"] = pd.to_datetime(additional_rcpts_df["date"])
# compute_expected_gap_ewma()
# create_item_supply_level_feat()
# add_item_total_purchase_count_feat()
# _build_trip_level_feats()
# build_school_schedule_features(): start
# build_school_schedule_features(): done
# build_holiday_features()
# build_trip_interveral_feautres(): start
# build_trip_interveral_feautres(): done
# drop_rare_purchases()
# validate_no_empty_columns()
# self._build_combined_df() done
# Building Live DF: Done
# Writing XLSX: ./live_df-2026_01_19_20_25_28.xlsx
# [W 2026-01-19 20:25:44,314] Trial 95 failed with parameters: {'learning_rate': 0.001, 'depth': 10, 'base_units': 1364, 'decay': 0.5677981047174572, 'embedding_dim': 20, 'epochs': 200} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\steve\AppData\Local\Temp\ipykernel_2808\3184304129.py", line 37, in new_objective
#     groceryML.run_experiment_with_consecutive_predictions( groceryML.training_df, build_params, train_params,  outputDir, start_date,  days)
#   File "C:\Users\steve\source\repos\grocery-ml\grocery_ml_tensorflow.py", line 446, in run_experiment_with_consecutive_predictions
#     artifacts = self.build_prediction_input(prediction_date, norm_params)
#   File "C:\Users\steve\source\repos\grocery-ml\grocery_ml_tensorflow.py", line 519, in build_prediction_input
#     self.groceryMLCore.export_df_to_excel_table(self.live_df, f"./live_df-{ts}")
#   File "C:\Users\steve\source\repos\grocery-ml\grocery_ml_core.py", line 433, in export_df_to_excel_table
#     workbook.save(file_path)
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\openpyxl\workbook\workbook.py", line 386, in save
#     save_workbook(self, filename)
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\openpyxl\writer\excel.py", line 294, in save_workbook
#     writer.save()
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\openpyxl\writer\excel.py", line 275, in save
#     self.write_data()
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\openpyxl\writer\excel.py", line 77, in write_data
#     self._write_worksheets()
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\openpyxl\writer\excel.py", line 215, in _write_worksheets
#     self.write_worksheet(ws)
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\openpyxl\writer\excel.py", line 200, in write_worksheet
#     writer.write()
#   File "openpyxl\\worksheet\\_writer.py", line 359, in openpyxl.worksheet._writer.WorksheetWriter.write
#   File "openpyxl\\worksheet\\_writer.py", line 123, in openpyxl.worksheet._writer.WorksheetWriter.write_rows
#   File "openpyxl\\worksheet\\_writer.py", line 125, in openpyxl.worksheet._writer.WorksheetWriter.write_rows
#   File "openpyxl\\worksheet\\_writer.py", line 135, in openpyxl.worksheet._writer.WorksheetWriter.write_row
#   File "openpyxl\\worksheet\\_writer.py", line 147, in openpyxl.worksheet._writer.WorksheetWriter.write_row
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\openpyxl\cell\_writer.py", line 86, in etree_write_cell
#     xf.write(el)
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\et_xmlfile\xmlfile.py", line 120, in write
#     incremental_tree._serialize_ns_xml(
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\et_xmlfile\incremental_tree.py", line 613, in _serialize_ns_xml
#     ) = write_elem_start(
#   File "C:\ProgramData\miniconda3\envs\grocery-ml-keras\lib\site-packages\et_xmlfile\incremental_tree.py", line 539, in write_elem_start
#     write("".join([f' {k}="{ET._escape_attrib(v)}"' for k, v in item_parts]))
# KeyboardInterrupt
# [W 2026-01-19 20:25:44,319] Trial 95 failed with value None.
#
# KeyboardInterrupt
